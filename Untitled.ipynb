# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
pd.set_option('display.max_columns', 152)
pd.set_option('display.max_rows', 152)

# %%
df = pd.read_csv('accepted_2007_to_2018Q4.csv')
df.drop('member_id',axis=1,inplace=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3049: DtypeWarning: Columns (0,19,49,59,118,129,130,131,134,135,136,139,145,146,147) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
print(df.shape)
df.sample(8)
# Out:
# (2260701, 150)
#                 id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 53093     65772426    11200.0      11200.0          11200.0   36 months
# 1573660  131789172    30000.0      30000.0          30000.0   36 months
# 1061114   71894251    19500.0      19500.0          19500.0   36 months
# 326165    44976134     7750.0       7750.0           7750.0   36 months
# 1843073    5445180    16400.0      16400.0          16400.0   60 months
# 1478553  141198497    30000.0      30000.0          30000.0   60 months
# 1364628  144412277     6000.0       6000.0           6000.0   36 months
# 570368   117582794     5000.0       5000.0           5000.0   36 months
#
#          int_rate  installment grade sub_grade                     emp_title  \
# 53093       13.18       378.35     C        C3             Medical Secratary
# 1573660     13.58      1019.22     C        C2                         Owner
# 1061114     15.31       678.94     C        C5             Elegibility Tech
# 326165      17.86       279.64     D        D5  Medical Insurance Specialist
# 1843073     17.27       409.97     C        C5                         NTDPW
# 1478553     12.73       678.46     B        B5            M.R.I Technologist
# 1364628     23.40       233.52     E        E1       MECHANICAL TECHNICIAN 2
# 570368       5.32       150.58     A        A1             Nursing assistant
#
#         emp_length home_ownership  annual_inc verification_status   issue_d  \
# 53093       1 year           RENT     42000.0     Source Verified  Nov-2015
# 1573660    3 years       MORTGAGE    400000.0            Verified  Apr-2018
# 1061114   < 1 year           RENT     39000.0     Source Verified  Feb-2016
# 326165     2 years           RENT     23920.0            Verified  Apr-2015
# 1843073  10+ years       MORTGAGE     46000.0            Verified  May-2013
# 1478553    5 years           RENT     90000.0        Not Verified  Oct-2018
# 1364628   < 1 year           RENT     42500.0        Not Verified  Dec-2018
# 570368    < 1 year           RENT     48000.0        Not Verified  Aug-2017
#
#          loan_status pymnt_plan  \
# 53093     Fully Paid          n
# 1573660   Fully Paid          n
# 1061114   Fully Paid          n
# 326165   Charged Off          n
# 1843073   Fully Paid          n
# 1478553      Current          n
# 1364628      Current          n
# 570368       Current          n
#
#                                                        url  \
# 53093    https://lendingclub.com/browse/loanDetail.acti...
# 1573660  https://lendingclub.com/browse/loanDetail.acti...
# 1061114  https://lendingclub.com/browse/loanDetail.acti...
# 326165   https://lendingclub.com/browse/loanDetail.acti...
# 1843073  https://lendingclub.com/browse/loanDetail.acti...
# 1478553  https://lendingclub.com/browse/loanDetail.acti...
# 1364628  https://lendingclub.com/browse/loanDetail.acti...
# 570368   https://lendingclub.com/browse/loanDetail.acti...
#
#                                                       desc  \
# 53093                                                  NaN
# 1573660                                                NaN
# 1061114                                                NaN
# 326165                                                 NaN
# 1843073    Borrower added on 05/22/13 > credit card con...
# 1478553                                                NaN
# 1364628                                                NaN
# 570368                                                 NaN
#
#                     purpose                      title zip_code addr_state  \
# 53093    debt_consolidation         Debt consolidation    551xx         MN
# 1573660  debt_consolidation         Debt consolidation    806xx         CO
# 1061114         credit_card    Credit card refinancing    917xx         CA
# 326165   debt_consolidation         Debt consolidation    799xx         TX
# 1843073  debt_consolidation  credit card consolidation    141xx         NY
# 1478553  debt_consolidation         Debt consolidation    104xx         NY
# 1364628  debt_consolidation         Debt consolidation    907xx         CA
# 570368          credit_card    Credit card refinancing    104xx         NY
#
#            dti  delinq_2yrs earliest_cr_line  fico_range_low  fico_range_high  \
#
#
#          sec_app_open_acc  sec_app_revol_util  sec_app_open_act_il  \
# 53093                 NaN                 NaN                  NaN
# 1573660               NaN                 NaN                  NaN
# 1061114               NaN                 NaN                  NaN
# 326165                NaN                 NaN                  NaN
# 1843073               NaN                 NaN                  NaN
# 1478553              13.0                31.5                  2.0
# 1364628               NaN                 NaN                  NaN
# 570368               14.0                63.3                  3.0
#
#          sec_app_num_rev_accts  sec_app_chargeoff_within_12_mths  \
# 53093                      NaN                               NaN
# 1573660                    NaN                               NaN
# 1061114                    NaN                               NaN
# 326165                     NaN                               NaN
# 1843073                    NaN                               NaN
# 1478553                   19.0                               0.0
# 1364628                    NaN                               NaN
# 570368                    12.0                               0.0
#
#          sec_app_collections_12_mths_ex_med  \
# 53093                                   NaN
# 1573660                                 NaN
# 1061114                                 NaN
# 326165                                  NaN
# 1843073                                 NaN
# 1478553                                 0.0
# 1364628                                 NaN
# 570368                                  0.0
#
#          sec_app_mths_since_last_major_derog hardship_flag hardship_type  \
# 53093                                    NaN             N           NaN
# 1573660                                  NaN             N           NaN
# 1061114                                  NaN             N           NaN
# 326165                                   NaN             N           NaN
# 1843073                                  NaN             N           NaN
# 1478553                                  NaN             N           NaN
# 1364628                                  NaN             N           NaN
# 570368                                  37.0             N           NaN
#
#         hardship_reason hardship_status  deferral_term  hardship_amount  \
# 53093               NaN             NaN            NaN              NaN
# 1573660             NaN             NaN            NaN              NaN
# 1061114             NaN             NaN            NaN              NaN
# 326165              NaN             NaN            NaN              NaN
# 1843073             NaN             NaN            NaN              NaN
# 1478553             NaN             NaN            NaN              NaN
# 1364628             NaN             NaN            NaN              NaN
# 570368              NaN             NaN            NaN              NaN
#
#         hardship_start_date hardship_end_date payment_plan_start_date  \
# 53093                   NaN               NaN                     NaN
# 1573660                 NaN               NaN                     NaN
# 1061114                 NaN               NaN                     NaN
# 326165                  NaN               NaN                     NaN
# 1843073                 NaN               NaN                     NaN
# 1478553                 NaN               NaN                     NaN
# 1364628                 NaN               NaN                     NaN
# 570368                  NaN               NaN                     NaN
#
#          hardship_length  hardship_dpd hardship_loan_status  \
# 53093                NaN           NaN                  NaN
# 1573660              NaN           NaN                  NaN
# 1061114              NaN           NaN                  NaN
# 326165               NaN           NaN                  NaN
# 1843073              NaN           NaN                  NaN
# 1478553              NaN           NaN                  NaN
# 1364628              NaN           NaN                  NaN
# 570368               NaN           NaN                  NaN
#
#          orig_projected_additional_accrued_interest  \
# 53093                                           NaN
# 1573660                                         NaN
# 1061114                                         NaN
# 326165                                          NaN
# 1843073                                         NaN
# 1478553                                         NaN
# 1364628                                         NaN
# 570368                                          NaN
#
#          hardship_payoff_balance_amount  hardship_last_payment_amount  \
# 53093                               NaN                           NaN
# 1573660                             NaN                           NaN
# 1061114                             NaN                           NaN
# 326165                              NaN                           NaN
# 1843073                             NaN                           NaN
# 1478553                             NaN                           NaN
# 1364628                             NaN                           NaN
# 570368                              NaN                           NaN
#
#         disbursement_method debt_settlement_flag debt_settlement_flag_date  \
# 53093                  Cash                    N                       NaN
# 1573660                Cash                    N                       NaN
# 1061114                Cash                    N                       NaN
# 326165                 Cash                    N                       NaN
# 1843073                Cash                    N                       NaN
# 1478553                Cash                    N                       NaN
# 1364628                Cash                    N                       NaN
# 570368                 Cash                    N                       NaN
#
#         settlement_status settlement_date  settlement_amount  \
# 53093                 NaN             NaN                NaN
# 1573660               NaN             NaN                NaN
# 1061114               NaN             NaN                NaN
# 326165                NaN             NaN                NaN
# 1843073               NaN             NaN                NaN
# 1478553               NaN             NaN                NaN
# 1364628               NaN             NaN                NaN
# 570368                NaN             NaN                NaN
#
#          settlement_percentage  settlement_term
# 53093                      NaN              NaN
# 1573660                    NaN              NaN
# 1061114                    NaN              NaN
# 326165                     NaN              NaN
# 1843073                    NaN              NaN
# 1478553                    NaN              NaN
# 1364628                    NaN              NaN
# 570368                     NaN              NaN

# %%
# why do we have 33 missing value
temp = df[df['issue_d'].isna()]
temp.head(3)
# Out:
#                                                       id  loan_amnt  \
# 421095  Total amount funded in policy code 1: 6417608175        NaN
# 421096  Total amount funded in policy code 2: 1944088810        NaN
# 528961  Total amount funded in policy code 1: 1741781700        NaN
#
#         funded_amnt  funded_amnt_inv term  int_rate  installment grade  \
# 421095          NaN              NaN  NaN       NaN          NaN   NaN
# 421096          NaN              NaN  NaN       NaN          NaN   NaN
# 528961          NaN              NaN  NaN       NaN          NaN   NaN
#
#        sub_grade emp_title emp_length home_ownership  annual_inc  \
# 421095       NaN       NaN        NaN            NaN         NaN
# 421096       NaN       NaN        NaN            NaN         NaN
# 528961       NaN       NaN        NaN            NaN         NaN
#
#        verification_status issue_d loan_status pymnt_plan  url desc purpose  \
# 421095                 NaN     NaN         NaN        NaN  NaN  NaN     NaN
# 421096                 NaN     NaN         NaN        NaN  NaN  NaN     NaN
# 528961                 NaN     NaN         NaN        NaN  NaN  NaN     NaN
#
#        title zip_code addr_state  dti  delinq_2yrs earliest_cr_line  \
# 421095   NaN      NaN        NaN  NaN          NaN              NaN
# 421096   NaN      NaN        NaN  NaN          NaN              NaN
# 528961   NaN      NaN        NaN  NaN          NaN              NaN
#
#         fico_range_low  fico_range_high  inq_last_6mths  \
# 421095             NaN              NaN             NaN
# 421096             NaN              NaN             NaN
# 528961             NaN              NaN             NaN
#
#         mths_since_last_delinq  mths_since_last_record  open_acc  pub_rec  \
# 421095                     NaN                     NaN       NaN      NaN
# 421096                     NaN                     NaN       NaN      NaN
# 528961                     NaN                     NaN       NaN      NaN
#
#         revol_bal  revol_util  total_acc initial_list_status  out_prncp  \
# 421095        NaN         NaN        NaN                 NaN        NaN
# 421096        NaN         NaN        NaN                 NaN        NaN
# 528961        NaN         NaN        NaN                 NaN        NaN
#
#         out_prncp_inv  total_pymnt  total_pymnt_inv  total_rec_prncp  \
# 421095            NaN          NaN              NaN              NaN
# 421096            NaN          NaN              NaN              NaN
# 528961            NaN          NaN              NaN              NaN
#
#         total_rec_int  total_rec_late_fee  recoveries  \
# 421095            NaN                 NaN         NaN
# 421096            NaN                 NaN         NaN
# 528961            NaN                 NaN         NaN
#
#         collection_recovery_fee last_pymnt_d  last_pymnt_amnt next_pymnt_d  \
# 421095                      NaN          NaN              NaN          NaN
# 421096                      NaN          NaN              NaN          NaN
# 528961                      NaN          NaN              NaN          NaN
#
#        last_credit_pull_d  last_fico_range_high  last_fico_range_low  \
# 421095                NaN                   NaN                  NaN
# 421096                NaN                   NaN                  NaN
# 528961                NaN                   NaN                  NaN
#
#         collections_12_mths_ex_med  mths_since_last_major_derog  policy_code  \
# 421095                         NaN                          NaN          NaN
# 421096                         NaN                          NaN          NaN
# 528961                         NaN                          NaN          NaN
#
#        application_type  annual_inc_joint  dti_joint  \
# 421095              NaN               NaN        NaN
# 421096              NaN               NaN        NaN
# 528961              NaN               NaN        NaN
#
#        verification_status_joint  acc_now_delinq  tot_coll_amt  tot_cur_bal  \
# 421095                       NaN             NaN           NaN          NaN
# 421096                       NaN             NaN           NaN          NaN
# 528961                       NaN             NaN           NaN          NaN
#
#         open_acc_6m  open_act_il  open_il_12m  open_il_24m  \
# 421095          NaN          NaN          NaN          NaN
# 421096          NaN          NaN          NaN          NaN
# 528961          NaN          NaN          NaN          NaN
#
#         mths_since_rcnt_il  total_bal_il  il_util  open_rv_12m  open_rv_24m  \
# purpose                                        object
# title                                          object
# zip_code                                       object
# addr_state                                     object
# dti                                           float64
# delinq_2yrs                                   float64
# earliest_cr_line                               object
# fico_range_low                                float64
# fico_range_high                               float64
# inq_last_6mths                                float64
# mths_since_last_delinq                        float64
# mths_since_last_record                        float64
# open_acc                                      float64
# pub_rec                                       float64
# revol_bal                                     float64
# revol_util                                    float64
# total_acc                                     float64
# initial_list_status                            object
# out_prncp                                     float64
# out_prncp_inv                                 float64
# total_pymnt                                   float64
# total_pymnt_inv                               float64
# total_rec_prncp                               float64
# total_rec_int                                 float64
# total_rec_late_fee                            float64
# recoveries                                    float64
# collection_recovery_fee                       float64
# last_pymnt_d                                   object
# last_pymnt_amnt                               float64
# next_pymnt_d                                   object
# last_credit_pull_d                             object
# last_fico_range_high                          float64
# last_fico_range_low                           float64
# collections_12_mths_ex_med                    float64
# mths_since_last_major_derog                   float64
# policy_code                                   float64
# application_type                               object
# annual_inc_joint                              float64
# dti_joint                                     float64
# verification_status_joint                      object
# acc_now_delinq                                float64
# tot_coll_amt                                  float64
# tot_cur_bal                                   float64
# open_acc_6m                                   float64
# open_act_il                                   float64
# open_il_12m                                   float64
# open_il_24m                                   float64
# mths_since_rcnt_il                            float64
# total_bal_il                                  float64
# il_util                                       float64
# open_rv_12m                                   float64
# open_rv_24m                                   float64
# max_bal_bc                                    float64
# all_util                                      float64
# total_rev_hi_lim                              float64
# inq_fi                                        float64
# total_cu_tl                                   float64
# inq_last_12m                                  float64
# acc_open_past_24mths                          float64
# avg_cur_bal                                   float64
# bc_open_to_buy                                float64
# bc_util                                       float64
# chargeoff_within_12_mths                      float64
# delinq_amnt                                   float64
# mo_sin_old_il_acct                            float64
# mo_sin_old_rev_tl_op                          float64
# mo_sin_rcnt_rev_tl_op                         float64
# mo_sin_rcnt_tl                                float64
# mort_acc                                      float64
# mths_since_recent_bc                          float64
# mths_since_recent_bc_dlq                      float64
# mths_since_recent_inq                         float64
# mths_since_recent_revol_delinq                float64
# num_accts_ever_120_pd                         float64
# num_actv_bc_tl                                float64
# num_actv_rev_tl                               float64
# num_bc_sats                                   float64
# num_bc_tl                                     float64
# num_il_tl                                     float64
# num_op_rev_tl                                 float64
# num_rev_accts                                 float64
# num_rev_tl_bal_gt_0                           float64
# num_sats                                      float64
# num_tl_120dpd_2m                              float64
# num_tl_30dpd                                  float64
# num_tl_90g_dpd_24m                            float64
# num_tl_op_past_12m                            float64
# pct_tl_nvr_dlq                                float64
# percent_bc_gt_75                              float64
# pub_rec_bankruptcies                          float64
# tax_liens                                     float64
# tot_hi_cred_lim                               float64
# total_bal_ex_mort                             float64
# total_bc_limit                                float64
# total_il_high_credit_limit                    float64
# revol_bal_joint                               float64
# sec_app_fico_range_low                        float64
# sec_app_fico_range_high                       float64
# sec_app_earliest_cr_line                       object
# sec_app_inq_last_6mths                        float64
# sec_app_mort_acc                              float64
# sec_app_open_acc                              float64
# sec_app_revol_util                            float64
# sec_app_open_act_il                           float64
# sec_app_num_rev_accts                         float64
# sec_app_chargeoff_within_12_mths              float64
# sec_app_collections_12_mths_ex_med            float64
# sec_app_mths_since_last_major_derog           float64
# hardship_flag                                  object
# hardship_type                                  object
# hardship_reason                                object
# hardship_status                                object
# deferral_term                                 float64
# hardship_amount                               float64
# hardship_start_date                            object
# hardship_end_date                              object
# payment_plan_start_date                        object
# hardship_length                               float64
# hardship_dpd                                  float64
# hardship_loan_status                           object
# orig_projected_additional_accrued_interest    float64
# hardship_payoff_balance_amount                float64
# hardship_last_payment_amount                  float64
# disbursement_method                            object
# debt_settlement_flag                           object
# debt_settlement_flag_date                      object
# settlement_status                              object
# settlement_date                                object
# settlement_amount                             float64
# settlement_percentage                         float64
# settlement_term                               float64
# dtype: object

# %%
df.columns
# Out:
# Index(['id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv', 'term', 'int_rate',
#        'installment', 'grade', 'sub_grade', 'emp_title',
#        ...
#        'hardship_payoff_balance_amount', 'hardship_last_payment_amount',
#        'disbursement_method', 'debt_settlement_flag',
#        'debt_settlement_flag_date', 'settlement_status', 'settlement_date',
#        'settlement_amount', 'settlement_percentage', 'settlement_term'],
#       dtype='object', length=150)

# %%
df.isnull().sum()
# Out:
# id                                                  0
# loan_amnt                                          33
# funded_amnt                                        33
# funded_amnt_inv                                    33
# term                                               33
# int_rate                                           33
# installment                                        33
# grade                                              33
# sub_grade                                          33
# emp_title                                      167002
# emp_length                                     146940
# home_ownership                                     33
# annual_inc                                         37
# verification_status                                33
# issue_d                                            33
# loan_status                                        33
# pymnt_plan                                         33
# url                                                33
# desc                                          2134634
# purpose                                            33
# title                                           23358
# zip_code                                           34
# addr_state                                         33
# dti                                              1744
# delinq_2yrs                                        62
# earliest_cr_line                                   62
# fico_range_low                                     33
# fico_range_high                                    33
# inq_last_6mths                                     63
# mths_since_last_delinq                        1158535
# mths_since_last_record                        1901545
# open_acc                                           62
# pub_rec                                            62
# revol_bal                                          33
# revol_util                                       1835
# total_acc                                          62
# initial_list_status                                33
# out_prncp                                          33
# out_prncp_inv                                      33
# total_pymnt                                        33
# total_pymnt_inv                                    33
# total_rec_prncp                                    33
# total_rec_int                                      33
# total_rec_late_fee                                 33
# recoveries                                         33
# collection_recovery_fee                            33
# last_pymnt_d                                     2460
# last_pymnt_amnt                                    33
# next_pymnt_d                                  1345343
# last_credit_pull_d                                105
# last_fico_range_high                               33
# last_fico_range_low                                33
# collections_12_mths_ex_med                        178
# mths_since_last_major_derog                   1679926
# policy_code                                        33
# application_type                                   33
# annual_inc_joint                              2139991
# dti_joint                                     2139995
# verification_status_joint                     2144971
# acc_now_delinq                                     62
# tot_coll_amt                                    70309
# tot_cur_bal                                     70309
# open_acc_6m                                    866163
# open_act_il                                    866162
# open_il_12m                                    866162
# open_il_24m                                    866162
# mths_since_rcnt_il                             909957
# total_bal_il                                   866162
# il_util                                       1068883
# open_rv_12m                                    866162
# open_rv_24m                                    866162
# max_bal_bc                                     866162
# all_util                                       866381
# total_rev_hi_lim                                70309
# inq_fi                                         866162
# total_cu_tl                                    866163
# inq_last_12m                                   866163
# acc_open_past_24mths                            50063
# avg_cur_bal                                     70379
# bc_open_to_buy                                  74968
# bc_util                                         76104
# chargeoff_within_12_mths                          178
# delinq_amnt                                        62
# mo_sin_old_il_acct                             139104
# mo_sin_old_rev_tl_op                            70310
# mo_sin_rcnt_rev_tl_op                           70310
# mo_sin_rcnt_tl                                  70309
# mort_acc                                        50063
# mths_since_recent_bc                            73445
# mths_since_recent_bc_dlq                      1741000
# mths_since_recent_inq                          295468
# mths_since_recent_revol_delinq                1520342
# num_accts_ever_120_pd                           70309
# num_actv_bc_tl                                  70309
# num_actv_rev_tl                                 70309
# num_bc_sats                                     58623
# num_bc_tl                                       70309
# num_il_tl                                       70309
# num_op_rev_tl                                   70309
# num_rev_accts                                   70310
# num_rev_tl_bal_gt_0                             70309
# num_sats                                        58623
# num_tl_120dpd_2m                               153690
# num_tl_30dpd                                    70309
# num_tl_90g_dpd_24m                              70309
# num_tl_op_past_12m                              70309
# pct_tl_nvr_dlq                                  70464
# percent_bc_gt_75                                75412
# pub_rec_bankruptcies                             1398
# tax_liens                                         138
# tot_hi_cred_lim                                 70309
# total_bal_ex_mort                               50063
# total_bc_limit                                  50063
# total_il_high_credit_limit                      70309
# revol_bal_joint                               2152681
# sec_app_fico_range_low                        2152680
# sec_app_fico_range_high                       2152680
# sec_app_earliest_cr_line                      2152680
# sec_app_inq_last_6mths                        2152680
# sec_app_mort_acc                              2152680
# sec_app_open_acc                              2152680
# sec_app_revol_util                            2154517
# sec_app_open_act_il                           2152680
# sec_app_num_rev_accts                         2152680
# sec_app_chargeoff_within_12_mths              2152680
# sec_app_collections_12_mths_ex_med            2152680
# sec_app_mths_since_last_major_derog           2224759
# hardship_flag                                      33
# hardship_type                                 2249784
# hardship_reason                               2249784
# hardship_status                               2249784
# deferral_term                                 2249784
# hardship_amount                               2249784
# hardship_start_date                           2249784
# hardship_end_date                             2249784
# payment_plan_start_date                       2249784
# hardship_length                               2249784
# hardship_dpd                                  2249784
# hardship_loan_status                          2249784
# orig_projected_additional_accrued_interest    2252050
# hardship_payoff_balance_amount                2249784
# hardship_last_payment_amount                  2249784
# disbursement_method                                33
# debt_settlement_flag                               33
# debt_settlement_flag_date                     2226455
# settlement_status                             2226455
# settlement_date                               2226455
# settlement_amount                             2226455
# settlement_percentage                         2226455
# settlement_term                               2226455
# dtype: int64

# %%
#df.drop(columns='member_id',inplace=True)

# %%
df = df[df['issue_d'].notna()]

# %%
#df.sample(5)

# %%
set(df.loan_status)
# Out:
# {'Charged Off',
#  'Current',
#  'Default',
#  'Does not meet the credit policy. Status:Charged Off',
#  'Does not meet the credit policy. Status:Fully Paid',
#  'Fully Paid',
#  'In Grace Period',
#  'Late (16-30 days)',
#  'Late (31-120 days)'}

# %%
df['year']=df.issue_d.map(lambda x:int(x.split('-')[-1]))

# %%
df.sample(5)
# Out:
#                 id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
#
cash                    N                       NaN
#
#         settlement_status settlement_date  settlement_amount  \
# 44427                 NaN             NaN                NaN
# 170419                NaN             NaN                NaN
# 46782                 NaN             NaN                NaN
# 1655632               NaN             NaN                NaN
# 376031                NaN             NaN                NaN
#
#          settlement_percentage  settlement_term  year
# 44427                      NaN              NaN  2015
# 170419                     NaN              NaN  2015
# 46782                      NaN              NaN  2015
# 1655632                    NaN              NaN  2017
# 376031                     NaN              NaN  2015

# %%
# how does interest rate vary per year
sns.boxplot(x = 'year', y = 'int_rate', data = df) 
#1

# %%
df[df.loan_status=='Fully Paid'].groupby('year')['int_rate'].agg('median')
# Out:
# year
# 2007     9.96
# 2008    11.03
# 2009    12.21
# 2010    11.36
# 2011    11.49
# 2012    13.11
# 2013    13.98
# 2014    12.99
# 2015    11.53
# 2016    11.49
# 2017    12.62
# 2018    11.98
# Name: int_rate, dtype: float64

# %%
'''
    How does the issued loans vary year after year?
'''
sns.countplot(x='year',data=df)
df.year.value_counts(ascending=True).plot(kind='bar')
plt.xticks(rotation=0)
plt.ylabel('Frequency')
plt.title("Frequency of loan per year")
#2
# Out:
# Text(0.5, 1.0, 'Frequency of loan per year')

# %%
color = list('rgbkymc')
df.groupby('year')['loan_amnt'].agg('median').plot(kind='bar',color=color)
#sns.boxplot(x='year',y='loan_amnt',data =df)
plt.xlabel('Year')
plt.ylabel('average loan ammount')
plt.xticks(rotation=0)
plt.title('Average loan ammount issued per year')
#3
# Out:
# Text(0.5, 1.0, 'Average loan ammount issued per year')

# %%
med = []

temp = df[df.loan_status=='Fully Paid']
med.append(temp['loan_amnt'].median() )
sns.distplot(temp.loan_amnt,bins=50,kde=False,label='Fully Paid')
#plt.avxline(median)

temp = df[df.loan_status=='Charged Off']
med.append(temp['loan_amnt'].median() )
sns.distplot(temp.loan_amnt,bins=50,kde=False,label='default')

colors = ['r','k']
status = ['Fully Paid','defaulted loan']
for xc,c,s in zip(med,colors,status):
    plt.axvline(x=xc, label='median loan ammount for {} '.format(s), c=c)

plt.ylabel('Frequency')
plt.legend()
plt.title('Loan ammount Frequency for Fully paid and defaulted ')
#4
# Out:
# Text(0.5, 1.0, 'Loan ammount Frequency for Fully paid and defaulted ')

# %%
#df.groupby('grade')['int_rate'].agg({"":'median'}).unstack(1).plot(kind='bar')
sns.boxplot(x='grade',y='int_rate',data=df,order=['A','B','C','D','E','F','G'])
plt.xlabel('Grade')
#plt.xticks(["A","B","C","D","E","F","G"])
positions = range(0,7)
labels = ("A","B","C","D","E","F","G")
median = df.int_rate.median()
#plt.axhline(median,color='r',label = 'median interest rate for all loan',)

temp = df[df.loan_status=='Charged Off']
median =temp.int_rate.median()
plt.axhline(median,color='r',label = 'median interest rate for default loan',linestyle ="--")

temp = df[df.loan_status=='Fully Paid']
median =temp.int_rate.median()
plt.axhline(median,color='g',label = 'median interest rate for Fully paid loan loan',linestyle ="--")

plt.title('Average interest rate per Grade')
plt.legend(loc = 'upper left')
#5

# %%
g = sns.boxplot(x = 'grade', y = 'loan_amnt', hue ='term' ,data = df,order=['A','B','C','D','E','F','G']) 
g.legend(loc='center left', bbox_to_anchor=(1, 0.5), ncol=1)
# 6

# %%
# FICO credit score lower than 580 as very poor, 580–669 as fair, 670–739 as good, 740–799 as very good, and 800–850 as exceptional.
g = sns.boxplot(x = 'grade', y = 'fico_range_high', hue ='term' ,data = df,order=['A','B','C','D','E','F','G']) 
g.legend(loc='center left', bbox_to_anchor=(1, 0.5), ncol=1)
#7

# %%
g = sns.lineplot(x='year',y='int_rate',hue='grade',data=df,hue_order=['A','B','C','D','E','F','G'])
g.legend(loc='center left', bbox_to_anchor=(1, 0.5), ncol=1)
plt.xlabel('Year')
plt.title('interest rate by credit score')
plt.show()
#8

# %%
# laon with category G and interest rate < 7
temp = df[(df.int_rate>7) & (df.grade=='G')]
print(temp.shape)
temp.sample(3)
# Out:
# (12160, 151)
#                 id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 602285   114950952    28000.0      28000.0          28000.0   60 months
# 726665    76589025    15200.0      15200.0          15200.0   60 months
# 1695002   98925597    35000.0      35000.0          35000.0   60 months
#
#          int_rate  installment grade sub_grade         emp_title emp_length  \
# 602285      30.99       923.00     G        G5  General Foreman     2 years
# 726665      28.67       479.43     G        G4          Operator    2 years
# 1695002     30.84      1150.50     G        G2       Firefighter  10+ years
#
#         home_ownership  annual_inc verification_status   issue_d  loan_status  \
# 602285        MORTGAGE    130000.0     Source Verified  Aug-2017  Charged Off
# 726665            RENT     40000.0            Verified  Apr-2016  Charged Off
# 1695002       MORTGAGE    110000.0     Source Verified  Feb-2017  Charged Off
#
#         pymnt_plan                                                url desc  \
# 602285           n  https://lendingclub.com/browse/loanDetail.acti...  NaN
# 726665           n  https://lendingclub.com/browse/loanDetail.acti...  NaN
# 1695002          n  https://lendingclub.com/browse/loanDetail.acti...  NaN
#
#                     purpose               title zip_code addr_state    dti  \
# 602285   debt_consolidation  Debt consolidation    954xx         CA  20.53
# 726665   debt_consolidation  Debt consolidation    604xx         IL  25.44
# 1695002  debt_consolidation  Debt consolidation    936xx         CA  17.96
#
#          delinq_2yrs earliest_cr_line  fico_range_low  fico_range_high  \
# 602285           0.0         Nov-2003           675.0            679.0
# 726665           0.0         Oct-2012           705.0            709.0
# 1695002          4.0         Sep-1994           680.0            684.0
#
#          inq_last_6mths  mths_since_last_delinq  mths_since_last_record  \
# 602285              0.0                     NaN                     NaN
# 726665              0.0                     NaN                     NaN
# 1695002             1.0                    15.0                   116.0
#
#          open_acc  pub_rec  revol_bal  revol_util  total_acc  \
# 602285       24.0      0.0    38335.0        51.2       34.0
# 726665        3.0      0.0     3505.0        77.9        4.0
# 1695002      17.0      1.0    22358.0        66.7       25.0
#
#         initial_list_status  out_prncp  out_prncp_inv  total_pymnt  \
# 602285                    w        0.0            0.0     13901.21
# 726665                    f        0.0            0.0      7794.72
# 1695002                   f        0.0            0.0      6255.42
#
#          total_pymnt_inv  total_rec_prncp  total_rec_int  total_rec_late_fee  \
# 602285          13901.21          1748.46        5860.95                0.00
# 726665           7794.72          2068.33        5702.42               23.97
# 1695002          6255.42           508.45        1732.58                0.00
#
#          recoveries  collection_recovery_fee last_pymnt_d  last_pymnt_amnt  \
# 602285      6291.80                1132.5240     Apr-2018          1196.62
# 726665         0.00                   0.0000     Oct-2017           313.74
# 1695002     4014.39                 722.5902     May-2017          1150.50
#
#         next_pymnt_d last_credit_pull_d  last_fico_range_high  \
# 602285           NaN           Oct-2018                 499.0
# 726665           NaN           Feb-2019                 589.0
# 1695002          NaN           Oct-2017                 509.0
#
#          last_fico_range_low  collections_12_mths_ex_med  \
# 602285                   0.0                         0.0
# 726665                 585.0                         0.0
# 1695002                505.0                         0.0
#
#          mths_since_last_major_derog  policy_code application_type  \
# 602285                           NaN          1.0       Individual
# 726665                           NaN          1.0       Individual
# 1695002                          NaN          1.0       Individual
#
#          annual_inc_joint  dti_joint verification_status_joint  \
# 602285                NaN        NaN                       NaN
# 726665                NaN        NaN                       NaN
# 1695002               NaN        NaN                       NaN
#
#          acc_now_delinq  tot_coll_amt  tot_cur_bal  open_acc_6m  open_act_il  \
# 602285              0.0           0.0     486172.0          0.0          1.0
# 726665              0.0           0.0      31345.0          0.0          1.0
# 1695002             0.0           0.0     353652.0          2.0          4.0
#
#          open_il_12m  open_il_24m  mths_since_rcnt_il  total_bal_il  il_util  \
# 602285           0.0          1.0                20.0         712.0      6.0
# 726665           0.0          0.0                35.0       27840.0      NaN
# 1695002          0.0          3.0                23.0       41110.0     69.0
#
#          open_rv_12m  open_rv_24m  max_bal_bc  all_util  total_rev_hi_lim  \
# 602285           1.0          5.0     10678.0      45.0           74900.0
# 726665           0.0          0.0      1930.0      78.0            4500.0
# 1695002          2.0          4.0      8966.0      68.0           33500.0
#
#          inq_fi  total_cu_tl  inq_last_12m  acc_open_past_24mths  avg_cur_bal  \
#
cash                    N                       NaN
#
#         settlement_status settlement_date  settlement_amount  \
# 602285                NaN             NaN                NaN
# 726665                NaN             NaN                NaN
# 1695002               NaN             NaN                NaN
#
#          settlement_percentage  settlement_term  year
# 602285                     NaN              NaN  2017
# 726665                     NaN              NaN  2016
# 1695002                    NaN              NaN  2017

# %%
temp.loan_status.value_counts()
# Out:
# Fully Paid                                             4568
# Charged Off                                            4559
# Current                                                2463
# Late (31-120 days)                                      235
# Does not meet the credit policy. Status:Fully Paid      122
# In Grace Period                                         102
# Does not meet the credit policy. Status:Charged Off      72
# Late (16-30 days)                                        39
# Name: loan_status, dtype: int64

# %%
df.home_ownership.value_counts()
# Out:
# MORTGAGE    1111450
# RENT         894929
# OWN          253057
# ANY             996
# OTHER           182
# NONE             54
# Name: home_ownership, dtype: int64

# %%
df.loan_status.value_counts()
# Out:
# Fully Paid                                             1076751
# Current                                                 878317
# Charged Off                                             268559
# Late (31-120 days)                                       21467
# In Grace Period                                           8436
# Late (16-30 days)                                         4349
# Does not meet the credit policy. Status:Fully Paid        1988
# Does not meet the credit policy. Status:Charged Off        761
# Default                                                     40
# Name: loan_status, dtype: int64

# %%
temp = df[df.loan_status=='Charged Off']
temp.head()
# Out:
#           id  loan_amnt  funded_amnt  funded_amnt_inv        term  int_rate  \
# 13  66624733    18000.0      18000.0          18000.0   60 months     19.48
# 25  67849662     4225.0       4225.0           4225.0   36 months     14.85
# 30  67715283    16000.0      16000.0          16000.0   36 months     12.88
# 31  68341789    24250.0      24250.0          24250.0   60 months     24.24
# 33  68415473    25000.0      25000.0          25000.0   60 months     13.99
#
#     installment grade sub_grade              emp_title emp_length  \
# 13       471.70     E        E2       Software Manager    7 years
# 25       146.16     C        C5               mechanic    5 years
# 30       538.18     C        C2  Owner, Fee Appraiser   10+ years
# 31       701.01     F        F3        hvac technician    4 years
# 33       581.58     C        C4    Executive Assistant    9 years
#
#    home_ownership  annual_inc verification_status   issue_d  loan_status  \
# 13           RENT    150000.0        Not Verified  Dec-2015  Charged Off
# 25           RENT     35000.0     Source Verified  Dec-2015  Charged Off
# 30       MORTGAGE     65000.0        Not Verified  Dec-2015  Charged Off
# 31       MORTGAGE     75000.0        Not Verified  Dec-2015  Charged Off
# 33       MORTGAGE     79000.0        Not Verified  Dec-2015  Charged Off
#
#    pymnt_plan                                                url desc  \
# 13          n  https://lendingclub.com/browse/loanDetail.acti...  NaN
# 25          n  https://lendingclub.com/browse/loanDetail.acti...  NaN
# 30          n  https://lendingclub.com/browse/loanDetail.acti...  NaN
# 31          n  https://lendingclub.com/browse/loanDetail.acti...  NaN
# 33          n  https://lendingclub.com/browse/loanDetail.acti...  NaN
#
#                purpose               title zip_code addr_state    dti  \
# 13  debt_consolidation  Debt consolidation    916xx         CA   9.39
# 25  debt_consolidation  Debt consolidation    672xx         KS  15.22
# 30      small_business            Business    354xx         AL  18.96
# 31  debt_consolidation                 NaN    114xx         NY  20.84
# 33  debt_consolidation  Debt consolidation    212xx         MD  34.53
#
#     delinq_2yrs earliest_cr_line  fico_range_low  fico_range_high  \
# 13          0.0         Jun-2005           665.0            669.0
# 25          2.0         Jul-2011           725.0            729.0
# 30          0.0         Dec-1985           675.0            679.0
# 31          0.0         Apr-2007           660.0            664.0
# 33          0.0         Jun-2001           730.0            734.0
#
#     inq_last_6mths  mths_since_last_delinq  mths_since_last_record  open_acc  \
# 13             1.0                     NaN                    75.0      18.0
# 25             0.0                    18.0                     NaN       6.0
# 30             0.0                    33.0                    66.0       7.0
# 31             0.0                     NaN                     NaN      18.0
# 33             1.0                     NaN                     NaN      33.0
#
#     pub_rec  revol_bal  revol_util  total_acc initial_list_status  out_prncp  \
# 13      1.0    14052.0        40.7       27.0                   w        0.0
# 25      0.0     1058.0        24.6        6.0                   w        0.0
# 30      1.0     5157.0        54.3       20.0                   w        0.0
# 31      0.0    24799.0        65.3       21.0                   w        0.0
# 33      0.0    22519.0        18.6       72.0                   w        0.0
#
#     out_prncp_inv  total_pymnt  total_pymnt_inv  total_rec_prncp  \
# 13            0.0      9452.74          9452.74          3481.86
# 25            0.0      2558.87          2558.87          1536.90
# 30            0.0     17396.63         17396.63         13833.12
# 31            0.0      4124.42          4124.42          1332.69
# 33            0.0     14490.92         14490.92          8364.55
#
#     total_rec_int  total_rec_late_fee  recoveries  collection_recovery_fee  \
#
_actv_rev_tl  num_bc_sats  num_bc_tl  num_il_tl  num_op_rev_tl  \
# 13             13.0          7.0        8.0        6.0           16.0
# 25              2.0          3.0        3.0        1.0            5.0
# 30              5.0          3.0        3.0       12.0            5.0
# 31             12.0         11.0       12.0        2.0           15.0
# 33             16.0         12.0       21.0       15.0           29.0
#
#     num_rev_accts  num_rev_tl_bal_gt_0  num_sats  num_tl_120dpd_2m  \
# 13           19.0                 13.0      18.0               0.0
# 25            5.0                  2.0       6.0               0.0
# 30            7.0                  5.0       7.0               0.0
# 31           16.0                 12.0      18.0               0.0
# 33           51.0                 16.0      33.0               0.0
#
#     num_tl_30dpd  num_tl_90g_dpd_24m  num_tl_op_past_12m  pct_tl_nvr_dlq  \
# 13           0.0                 0.0                 3.0           100.0
# 25           0.0                 0.0                 0.0            66.7
# 30           0.0                 0.0                 2.0            80.0
# 31           0.0                 0.0                 3.0           100.0
# 33           0.0                 0.0                 6.0           100.0
#
#     percent_bc_gt_75  pub_rec_bankruptcies  tax_liens  tot_hi_cred_lim  \
# 13              14.3                   1.0        0.0          65819.0
# 25               0.0                   0.0        0.0          21822.0
# 30               0.0                   0.0        1.0          80999.0
# 31              63.6                   0.0        0.0         344960.0
# 33               0.0                   0.0        0.0         389002.0
#
#     total_bal_ex_mort  total_bc_limit  total_il_high_credit_limit  \
# 13            36247.0         10300.0                     31319.0
# 25             4888.0          2600.0                     17522.0
# 30            39781.0          4700.0                     71499.0
# 31            38475.0         29100.0                     18300.0
# 33            89978.0         72600.0                     81802.0
#
#     revol_bal_joint  sec_app_fico_range_low  sec_app_fico_range_high  \
# 13              NaN                     NaN                      NaN
# 25              NaN                     NaN                      NaN
# 30              NaN                     NaN                      NaN
# 31              NaN                     NaN                      NaN
# 33              NaN                     NaN                      NaN
#
#    sec_app_earliest_cr_line  sec_app_inq_last_6mths  sec_app_mort_acc  \
# 13                      NaN                     NaN               NaN
# 25                      NaN                     NaN               NaN
# 30                      NaN                     NaN               NaN
# 31                      NaN                     NaN               NaN
# 33                      NaN                     NaN               NaN
#
#     sec_app_open_acc  sec_app_revol_util  sec_app_open_act_il  \
# 13               NaN                 NaN                  NaN
# 25               NaN                 NaN                  NaN
# 30               NaN                 NaN                  NaN
# 31               NaN                 NaN                  NaN
# 33               NaN                 NaN                  NaN
#
#     sec_app_num_rev_accts  sec_app_chargeoff_within_12_mths  \
# 13                    NaN                               NaN
# 25                    NaN                               NaN
# 30                    NaN                               NaN
# 31                    NaN                               NaN
# 33                    NaN                               NaN
#
#     sec_app_collections_12_mths_ex_med  sec_app_mths_since_last_major_derog  \
# 13                                 NaN                                  NaN
# 25                                 NaN                                  NaN
# 30                                 NaN                                  NaN
# 31                                 NaN                                  NaN
# 33                                 NaN                                  NaN
#
#    hardship_flag hardship_type hardship_reason hardship_status  deferral_term  \
# 13             N           NaN             NaN             NaN            NaN
# 25             N           NaN             NaN             NaN            NaN
# 30             N           NaN             NaN             NaN            NaN
# 31             N           NaN             NaN             NaN            NaN
# 33             N           NaN             NaN             NaN            NaN
#
#     hardship_amount hardship_start_date hardship_end_date  \
# 13              NaN                 NaN               NaN
# 25              NaN                 NaN               NaN
# 30              NaN                 NaN               NaN
# 31              NaN                 NaN               NaN
# 33              NaN                 NaN               NaN
#
#    payment_plan_start_date  hardship_length  hardship_dpd  \
# 13                     NaN              NaN           NaN
# 25                     NaN              NaN           NaN
# 30                     NaN              NaN           NaN
# 31                     NaN              NaN           NaN
# 33                     NaN              NaN           NaN
#
#    hardship_loan_status  orig_projected_additional_accrued_interest  \
# 13                  NaN                                         NaN
# 25                  NaN                                         NaN
# 30                  NaN                                         NaN
# 31                  NaN                                         NaN
# 33                  NaN                                         NaN
#
#     hardship_payoff_balance_amount  hardship_last_payment_amount  \
# 13                             NaN                           NaN
# 25                             NaN                           NaN
# 30                             NaN                           NaN
# 31                             NaN                           NaN
# 33                             NaN                           NaN
#
#    disbursement_method debt_settlement_flag debt_settlement_flag_date  \
# 13                Cash                    N                       NaN
# 25                Cash                    N                       NaN
# 30                Cash                    N                       NaN
# 31                Cash                    N                       NaN
# 33                Cash                    N                       NaN
#
#    settlement_status settlement_date  settlement_amount  \
# 13               NaN             NaN                NaN
# 25               NaN             NaN                NaN
# 30               NaN             NaN                NaN
# 31               NaN             NaN                NaN
# 33               NaN             NaN                NaN
#
#     settlement_percentage  settlement_term  year
# 13                    NaN              NaN  2015
# 25                    NaN              NaN  2015
# 30                    NaN              NaN  2015
# 31                    NaN              NaN  2015
# 33                    NaN              NaN  2015

# %%
df.acc_now_delinq.value_counts(dropna=False)
# Out:
# 0.0     2251857
# 1.0        8293
# 2.0         421
# 3.0          50
# NaN          29
# 4.0          11
# 5.0           3
# 6.0           2
# 14.0          1
# 7.0           1
# Name: acc_now_delinq, dtype: int64

# %%
temp = temp[['grade','year']]
temp.sample(5)
# Out:
#         grade  year
# 2010857     D  2016
# 2015961     C  2016
# 285888      C  2015
# 116330      B  2015
# 1769872     F  2013

# %%
# Frequency of loan per class
# A is increasing the most towards the year
plt.rcParams["figure.figsize"] = [15, 5]
g = df.groupby(['year'])['grade'].value_counts().unstack(1).plot(kind='bar',)
g.legend(loc='center left', bbox_to_anchor=(1, 0.5), ncol=1)
plt.xticks(rotation=0)
plt.title('Frequency of loan per class')
#9
# Out:
# Text(0.5, 1.0, 'Frequency of loan per class')

# %%
'''
add percentage 
'''
# Out:
# '\nadd percentage \n'

# %%
# Frequency of loan per class 
plt.rcParams["figure.figsize"] = [15, 5]
g = temp.groupby(['year'])['grade'].value_counts().unstack(1).plot(kind='bar',)
g.legend(loc='center left', bbox_to_anchor=(1, 0.5), ncol=1)
plt.xticks(rotation=0)
plt.title('Frequency of  charged off loan per year for each class ')
# Out:
# Text(0.5, 1.0, 'Frequency of  charged off loan per year for each class ')

# %%
'''
try to plot for each year by purpose
'''
# Out:
# '\ntry to plot for each year by purpose\n'

# %%
df.head()
# Out:
#          id  loan_amnt  funded_amnt  funded_amnt_inv        term  int_rate  \
# 0  68407277     3600.0       3600.0           3600.0   36 months     13.99
# 1  68355089    24700.0      24700.0          24700.0   36 months     11.99
# 2  68341763    20000.0      20000.0          20000.0   60 months     10.78
# 3  66310712    35000.0      35000.0          35000.0   60 months     14.85
# 4  68476807    10400.0      10400.0          10400.0   60 months     22.45
#
#    installment grade sub_grade                    emp_title emp_length  \
# 0       123.03     C        C4                      leadman  10+ years
# 1       820.28     C        C1                     Engineer  10+ years
# 2       432.66     B        B4                 truck driver  10+ years
# 3       829.90     C        C5  Information Systems Officer  10+ years
# 4       289.91     F        F1          Contract Specialist    3 years
#
#   home_ownership  annual_inc verification_status   issue_d loan_status  \
# 0       MORTGAGE     55000.0        Not Verified  Dec-2015  Fully Paid
# 1       MORTGAGE     65000.0        Not Verified  Dec-2015  Fully Paid
# 2       MORTGAGE     63000.0        Not Verified  Dec-2015  Fully Paid
# 3       MORTGAGE    110000.0     Source Verified  Dec-2015     Current
# 4       MORTGAGE    104433.0     Source Verified  Dec-2015  Fully Paid
#
#   pymnt_plan                                                url desc  \
# 0          n  https://lendingclub.com/browse/loanDetail.acti...  NaN
# 1          n  https://lendingclub.com/browse/loanDetail.acti...  NaN
# 2          n  https://lendingclub.com/browse/loanDetail.acti...  NaN
# 3          n  https://lendingclub.com/browse/loanDetail.acti...  NaN
# 4          n  https://lendingclub.com/browse/loanDetail.acti...  NaN
#
#               purpose               title zip_code addr_state    dti  \
# 0  debt_consolidation  Debt consolidation    190xx         PA   5.91
# 1      small_business            Business    577xx         SD  16.06
# 2    home_improvement                 NaN    605xx         IL  10.78
# 3  debt_consolidation  Debt consolidation    076xx         NJ  17.06
# 4      major_purchase      Major purchase    174xx         PA  25.37
#
#    delinq_2yrs earliest_cr_line  fico_range_low  fico_range_high  \
# 0          0.0         Aug-2003           675.0            679.0
# 1          1.0         Dec-1999           715.0            719.0
# 2          0.0         Aug-2000           695.0            699.0
# 3          0.0         Sep-2008           785.0            789.0
# 4          1.0         Jun-1998           695.0            699.0
#
#    inq_last_6mths  mths_since_last_delinq  mths_since_last_record  open_acc  \
# 0             1.0                    30.0                     NaN       7.0
# 1             4.0                     6.0                     NaN      22.0
# 2             0.0                     NaN                     NaN       6.0
# 3             0.0                     NaN                     NaN      13.0
# 4             3.0                    12.0                     NaN      12.0
#
#    pub_rec  revol_bal  revol_util  total_acc initial_list_status  out_prncp  \
# 0      0.0     2765.0        29.7       13.0                   w       0.00
# 1      0.0    21470.0        19.2       38.0                   w       0.00
# 2      0.0     7869.0        56.2       18.0                   w       0.00
# 3      0.0     7802.0        11.6       17.0                   w   15897.65
# 4      0.0    21929.0        64.5       35.0                   w       0.00
#
#    out_prncp_inv   total_pymnt  total_pymnt_inv  total_rec_prncp  \
# 0           0.00   4421.723917          4421.72          3600.00
# 1           0.00  25679.660000         25679.66         24700.00
# 2           0.00  22705.924294         22705.92         20000.00
# 3       15897.65  31464.010000         31464.01         19102.35
# 4           0.00  11740.500000         11740.50         10400.00
#
#    total_rec_int  total_rec_late_fee  recoveries  collection_recovery_fee  \
# 0         821.72                 0.0         0.0                      0.0
# 1         979.66                 0.0         0.0                      0.0
# 2        2705.92                 0.0         0.0                      0.0
# 3       12361.66                 0.0         0.0                      0.0
# 4        1340.50                 0.0         0.0                      0.0
#
#   last_pymnt_d  last_pymnt_amnt next_pymnt_d last_credit_pull_d  \
# 0     Jan-2019           122.67          NaN           Mar-2019
# 1     Jun-2016           926.35          NaN           Mar-2019
# 2     Jun-2017         15813.30          NaN           Mar-2019
# 3     Feb-2019           829.90     Apr-2019           Mar-2019
# 4     Jul-2016         10128.96          NaN           Mar-2018
#
#    last_fico_range_high  last_fico_range_low  collections_12_mths_ex_med  \
# 0                 564.0                560.0                         0.0
# 1                 699.0                695.0                         0.0
# 2                 704.0                700.0                         0.0
# 3                 679.0                675.0                         0.0
# 4                 704.0                700.0                         0.0
#
#    mths_since_last_major_derog  policy_code application_type  \
# 0                         30.0          1.0       Individual
# 1                          NaN          1.0       Individual
# 2                          NaN          1.0        Joint App
# 3                          NaN          1.0       Individual
# 4                          NaN          1.0       Individual
#
#    annual_inc_joint  dti_joint verification_status_joint  acc_now_delinq  \
# 0               NaN        NaN                       NaN             0.0
# 1               NaN        NaN                       NaN             0.0
# 2           71000.0      13.85              Not Verified             0.0
# 3               NaN        NaN                       NaN             0.0
# 4               NaN        NaN                       NaN             0.0
#
#    tot_coll_amt  tot_cur_bal  open_acc_6m  open_act_il  open_il_12m  \
# 0         722.0     144904.0          2.0          2.0          0.0
# 1           0.0     204396.0          1.0          1.0          0.0
# 2           0.0     189699.0          0.0          1.0          0.0
# 3           0.0     301500.0          1.0          1.0          0.0
# 4           0.0     331730.0          1.0          3.0          0.0
#
#    open_il_24m  mths_since_rcnt_il  total_bal_il  il_util  open_rv_12m  \
# 0          1.0                21.0        4981.0     36.0          3.0
# 1          1.0                19.0       18005.0     73.0          2.0
# 2          4.0                19.0       10827.0     73.0          0.0
# 3          1.0                23.0       12609.0     70.0          1.0
# 4          3.0                14.0       73839.0     84.0          4.0
#
#    open_rv_24m  max_bal_bc  all_util  total_rev_hi_lim  inq_fi  total_cu_tl  \
# 0          3.0       722.0      34.0            9300.0     3.0          1.0
# 1          3.0      6472.0      29.0          111800.0     0.0          0.0
# 2          2.0      2081.0      65.0           14000.0     2.0          5.0
# 3          1.0      6987.0      45.0           67300.0     0.0          1.0
# 4          7.0      9702.0      78.0           34000.0     2.0          1.0
#
#    inq_last_12m  acc_open_past_24mths  avg_cur_bal  bc_open_to_buy  bc_util  \
# 0           4.0                   4.0      20701.0          1506.0     37.2
# 1           6.0                   4.0       9733.0         57830.0     27.1
# 2           1.0                   6.0      31617.0          2737.0     55.9
# 3           0.0                   2.0      23192.0         54962.0     12.1
# 4           3.0                  10.0      27644.0          4567.0     77.5
#
#    chargeoff_within_12_mths  delinq_amnt  mo_sin_old_il_acct  \
# 0                       0.0          0.0               148.0
# 1                       0.0          0.0               113.0
# 2                       0.0          0.0               125.0
# 3                       0.0          0.0                36.0
# 4                       0.0          0.0               128.0
#
#    mo_sin_old_rev_tl_op  mo_sin_rcnt_rev_tl_op  mo_sin_rcnt_tl  mort_acc  \
# 0                 128.0                    3.0             3.0       1.0
# 1                 192.0                    2.0             2.0       4.0
# 2                 184.0                   14.0            14.0       5.0
# 3                  87.0                    2.0             2.0       1.0
# 4                 210.0                    4.0             4.0       6.0
#
#    mths_since_recent_bc  mths_since_recent_bc_dlq  mths_since_recent_inq  \
# 0                   4.0                      69.0                    4.0
# 1                   2.0                       NaN                    0.0
# 2                 101.0                       NaN                   10.0
# 3                   2.0                       NaN                    NaN
# 4                   4.0                      12.0                    1.0
#
#    mths_since_recent_revol_delinq  num_accts_ever_120_pd  num_actv_bc_tl  \
# 0                            69.0                    2.0             2.0
# 1                             6.0                    0.0             5.0
# 2                             NaN                    0.0             2.0
# 3                             NaN                    0.0             4.0
# 4                            12.0                    0.0             4.0
#
#    num_actv_rev_tl  num_bc_sats  num_bc_tl  num_il_tl  num_op_rev_tl  \
# 0              4.0          2.0        5.0        3.0            4.0
# 1              5.0         13.0       17.0        6.0           20.0
# 2              3.0          2.0        4.0        6.0            4.0
# 3              5.0          8.0       10.0        2.0           10.0
# 4              6.0          5.0        9.0       10.0            7.0
#
#    num_rev_accts  num_rev_tl_bal_gt_0  num_sats  num_tl_120dpd_2m  \
# 0            9.0                  4.0       7.0               0.0
# 1           27.0                  5.0      22.0               0.0
# 2            7.0                  3.0       6.0               0.0
# 3           13.0                  5.0      13.0               0.0
# 4           19.0                  6.0      12.0               0.0
#
#    num_tl_30dpd  num_tl_90g_dpd_24m  num_tl_op_past_12m  pct_tl_nvr_dlq  \
# 0           0.0                 0.0                 3.0            76.9
# 1           0.0                 0.0                 2.0            97.4
# 2           0.0                 0.0                 0.0           100.0
# 3           0.0                 0.0                 1.0           100.0
# 4           0.0                 0.0                 4.0            96.6
#
#    percent_bc_gt_75  pub_rec_bankruptcies  tax_liens  tot_hi_cred_lim  \
# 0               0.0                   0.0        0.0         178050.0
# 1               7.7                   0.0        0.0         314017.0
# 2              50.0                   0.0        0.0         218418.0
# 3               0.0                   0.0        0.0         381215.0
# 4              60.0                   0.0        0.0         439570.0
#
#    total_bal_ex_mort  total_bc_limit  total_il_high_credit_limit  \
# 0             7746.0          2400.0                     13734.0
# 1            39475.0         79300.0                     24667.0
# 2            18696.0          6200.0                     14877.0
# 3            52226.0         62500.0                     18000.0
# 4            95768.0         20300.0                     88097.0
#
#    revol_bal_joint  sec_app_fico_range_low  sec_app_fico_range_high  \
# 0              NaN                     NaN                      NaN
# 1              NaN                     NaN                      NaN
# 2              NaN                     NaN                      NaN
# 3              NaN                     NaN                      NaN
# 4              NaN                     NaN                      NaN
#
#   sec_app_earliest_cr_line  sec_app_inq_last_6mths  sec_app_mort_acc  \
# 0                      NaN                     NaN               NaN
# 1                      NaN                     NaN               NaN
# 2                      NaN                     NaN               NaN
# 3                      NaN                     NaN               NaN
# 4                      NaN                     NaN               NaN
#
#    sec_app_open_acc  sec_app_revol_util  sec_app_open_act_il  \
# 0               NaN                 NaN                  NaN
# 1               NaN                 NaN                  NaN
# 2               NaN                 NaN                  NaN
# 3               NaN                 NaN                  NaN
# 4               NaN                 NaN                  NaN
#
#    sec_app_num_rev_accts  sec_app_chargeoff_within_12_mths  \
# 0                    NaN                               NaN
# 1                    NaN                               NaN
# 2                    NaN                               NaN
# 3                    NaN                               NaN
# 4                    NaN                               NaN
#
#    sec_app_collections_12_mths_ex_med  sec_app_mths_since_last_major_derog  \
# 0                                 NaN                                  NaN
# 1                                 NaN                                  NaN
# 2                                 NaN                                  NaN
# 3                                 NaN                                  NaN
# 4                                 NaN                                  NaN
#
#   hardship_flag hardship_type hardship_reason hardship_status  deferral_term  \
# 0             N           NaN             NaN             NaN            NaN
# 1             N           NaN             NaN             NaN            NaN
# 2             N           NaN             NaN             NaN            NaN
# 3             N           NaN             NaN             NaN            NaN
# 4             N           NaN             NaN             NaN            NaN
#
#    hardship_amount hardship_start_date hardship_end_date  \
# 0              NaN                 NaN               NaN
# 1              NaN                 NaN               NaN
# 2              NaN                 NaN               NaN
# 3              NaN                 NaN               NaN
# 4              NaN                 NaN               NaN
#
#   payment_plan_start_date  hardship_length  hardship_dpd hardship_loan_status  \
# 0                     NaN              NaN           NaN                  NaN
# 1                     NaN              NaN           NaN                  NaN
# 2                     NaN              NaN           NaN                  NaN
# 3                     NaN              NaN           NaN                  NaN
# 4                     NaN              NaN           NaN                  NaN
#
#    orig_projected_additional_accrued_interest  hardship_payoff_balance_amount  \
# 0                                         NaN                             NaN
# 1                                         NaN                             NaN
# 2                                         NaN                             NaN
# 3                                         NaN                             NaN
# 4                                         NaN                             NaN
#
#    hardship_last_payment_amount disbursement_method debt_settlement_flag  \
# 0                           NaN                Cash                    N
# 1                           NaN                Cash                    N
# 2                           NaN                Cash                    N
# 3                           NaN                Cash                    N
# 4                           NaN                Cash                    N
#
#   debt_settlement_flag_date settlement_status settlement_date  \
# 0                       NaN               NaN             NaN
# 1                       NaN               NaN             NaN
# 2                       NaN               NaN             NaN
# 3                       NaN               NaN             NaN
# 4                       NaN               NaN             NaN
#
#    settlement_amount  settlement_percentage  settlement_term  year
# 0                NaN                    NaN              NaN  2015
# 1                NaN                    NaN              NaN  2015
# 2                NaN                    NaN              NaN  2015
# 3                NaN                    NaN              NaN  2015
# 4                NaN                    NaN              NaN  2015

# %%
chart = sns.barplot(x='purpose',data=df,hue='year',order = df.purpose.value_counts().index,)#,color='loan_status')
chart.set_xticklabels(chart.get_xticklabels(), rotation=45)
plt.legend(loc='upper right')

# %%
# What are the purposes of applying Lending Club loans?
#df.purpose.value_counts().plot(kind='bar')
chart = sns.countplot(x='purpose',data=df,hue='year',order = df.purpose.value_counts().index,)#,color='loan_status')
chart.set_xticklabels(chart.get_xticklabels(), rotation=45)
plt.legend(loc='upper right')

# %%
# What are the purposes of applying Lending Club loans?
#df.purpose.value_counts().plot(kind='bar')
chart = sns.barplot(x='purpose',data=df,hue='year',order = df.purpose.value_counts().index,)#,color='loan_status')
chart.set_xticklabels(chart.get_xticklabels(), rotation=45)
plt.legend(loc='upper right')

# %%
L = ["Charged Off","Fully Paid"]
temp = df[  (df.loan_status==L[0] ) | (df.loan_status==L[1]) ]
#chart = sns.boxplot(x='purpose',data=temp,color='purpose')#,order = temp.purpose.value_counts().index,dodge=False,)
#chart.set_xticklabels(chart.get_xticklabels(), rotation=45)
#plt.legend(loc='right')

# %%
chart = sns.boxplot(x='purpose',y='int_rate',data=df,order = df.groupby("purpose")['int_rate'].median().sort_values().index)
chart.set_xticklabels(chart.get_xticklabels(), rotation=45)
plt.title('different purposes with their interest rate')

# %%
(df[df.purpose=='educational']).loan_status.value_counts()

# %%
# Do you observe different loan grade patterns for different loan purposes?
plt.rcParams["figure.figsize"] = [15, 5]
#g = temp.groupby(['year'])['grade'].value_counts(normalize=True).unstack(1).plot(kind='bar',)
g = df.groupby('grade')['purpose'].value_counts(normalize=True).unstack(1).plot(kind='bar')
plt.xticks(rotation=0)
g.legend(loc='center left', bbox_to_anchor=(1, 0.5), ncol=1)

# %%
temp = df[df.purpose=='other']
temp.head()

# %%
temp.loan_status.value_counts()

# %%
df.groupby('term')['loan_status'].value_counts(normalize=True)

# %%
df.head()

# %%
# df.desc.value_counts()

# %%
L = ["MORTGAGE","RENT","OWN"]
temp = df[(df.home_ownership==L[0] )| ( df.home_ownership==L[1]) | (df.home_ownership==L[2] ) ]
temp.shape

# %%
g = sns.countplot(x = 'grade',data = temp,hue='home_ownership',order=['A','B','C','D','E','F','G']) 
g.legend(loc='center left', bbox_to_anchor=(1, 0.5), ncol=1)
plt.title('Distribution of loan_status by home_ownership ')

# %%
df.addr_state.value_counts(normalize=True)

# %%
# comparing income in Arkansans vs income in california
temp = df[(df.addr_state=='AK') |  (df.addr_state=='CA') | (df.addr_state=='NY') |( df.addr_state=='KY') |( df.addr_state=='HI')  ]
temp.head()

#temp = df[df.addr_state=='CA']
temp.head()


sns.boxplot(y='int_rate',x='addr_state',data=temp)#,order=temp.groupby("addr_state")['int_rate'].median().sort_values().index)
plt.title("average interest rate for borrower among diffrent states")

# %%
df.groupby("addr_state")['int_rate'].median().sort_values()

# %%
# relationm between number of employemnt year and int rate
import re
temp = df.copy()
#   str.replace(r'\D+', ''), errors='coerce')
temp['work_year'] = pd.to_numeric(temp.emp_length.str.replace(r'\D+', ''),  errors='coerce'   )
#temp['work_year'] = temp.emp_length.str.replace(r'\D+', '').astype(int)

# %%
temp = df[df.fico_range_high>800].copy()
print(temp.shape)
temp.head()

# %%
temp.loan_status.value_counts()

# %%
# the sum of all the loan you can incvest in
np.sum(temp.loan_amnt)

# %%
# average return for all loan that has a fico score > 800
total = np.sum(temp.loan_amnt)
temp['weight'] = temp.loan_amnt/total
temp['weight'] = temp['weight'] * temp.int_rate
np.sum(temp['weight'])

# %% [markdown]
#  #  1 USD in SP500 vs Lending club (Fico >800) FROM 2007 to 2018 (12 Year)
#  # 8.3 vs 7.26

# %%
# fv=pv(1+i)^n

# %%
set(df.loan_status)

# %%
df.loan_status.value_counts()

# %%
L = ["Charged Off","Fully Paid"]
temp = df[ ( (df.loan_status==L[0] ) | (df.loan_status==L[1]) ) & (df.annual_inc>5000) ]

temp.loan_status = temp.loan_status.map({'Charged Off':0,'Fully Paid':1})
temp.head()

# %%
sns.scatterplot(x='annual_inc',y='loan_status',data=temp)
plt.xlim(500,10000000)

# %%
temp.annual_inc.sort_values()

# %% [markdown]
# - Installment Credit: predetermined length and end date such as mortgage, car loan
# - Revolving Credit: No payment plan  higher interest rates such as credit card loan

# %% [markdown]
# - loan default: A loan goes into default—which is the eventual consequence of extended payment delinquency
# - loan delinquent: Payment delinquency is commonly used to describe a situation in which a borrower misses a single payment

# %% [markdown]
# - loan settlement is the act of paying back the amount of money owed to the lender
# - loan collection is the process of pursuing payments of debts owed by individuals or businesses

# %% [markdown]
# - 'Fully Paid', 'Current', 'Late', 'Grace period', 'Default', 'Charged Off'
# - late to default  before charged off
# - default: a note goes into Default status when it is 121 or more days past due.
# - Charge-Off:When a note is in Default status, Charge Off occurs no later than 150 days past due (i.e. No later than 30 days after the Default status is reached) when there is no reasonable expectation of sufficient payment to prevent the charge off.
# - After borrowers miss a loan payment, their loan will move from “current” to “late” status. When borrowers miss several payments, the loan will enter “default” status and, when there is no longer a reasonable expectation of further borrower payments, the loan will be “Charged-off.” Learn more about what happens when a loan is charged off.

# %% [markdown]
# - The debt-to-income (DTI) ratio is a personal finance measure that compares an individual’s monthly debt payment to their monthly gross income.
# - - Annualized Default Rate is calculated by dividing the total amount of loans in default by the total amount of loans issued for more than 120 days, divided by the number of months loans in default have been outstanding and multiplied by twelve. The loans issued for less than 120 days are excluded from the calculation because loans are unlikely to default during the first 120 days.

# %% [markdown]
# # Observation:

# %% [markdown]
#  - most of the loans are between 1000 and 40000
#  - borrower that default has a higher loan ammount than borrower that repaid their debt
#  - most of the loan issued are class B,C or D
#  - the primary purpose for a loan is debt consolidation(  Multiple debts are combined into a single, larger piece of debt)
#  - loan of the same class with a higher maturity tend to have higher interest rate
#  - the average interest rate is the same for all state and most of the people applying for loans are from most densily area
#  -
